# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic=Image.open("../DATA/puppy.jpg")

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
pic_red=pic_arr.copy()

# %%
#0 -red channel 1 -green channel 2-blue channel
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
pic_red.shape # still has 3 channels its just we are only outputting 0th channel or red, same can be done with blue and green.
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_red[:,:,1],cmap='gray')  #green channel

# %%
plt.imshow(pic_red[:,:,2],cmap='gray')  #blue channel

# %%
pic_red_1d=pic_red.copy()

# %%
pic_red[:,:,0].shape
# Out:
# (1300, 1950)

# %%
pic_red_1d[:,:,1]=0
pic_red_1d[:,:,2]=0
pic_red_1d.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_red_1d)

# %%
pic_green=pic_red.copy()

# %%
pic_green[:,:,0]=0
pic_green[:,:,2]=0
plt.imshow(pic_green)

# %%
pic_blue=pic_red.copy()

# %%
pic_blue[:,:,0]=0
pic_blue[:,:,1]=0
plt.imshow(pic_blue)
