# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
flat_chess=cv2.imread("../DATA/flat_chessboard.png")
flat_chess=cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)
plt.imshow(flat_chess)

# %%
real_chess=cv2.imread("../DATA/real_chessboard.jpg")
real_chess=cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)
plt.imshow(real_chess)

# %%
flat_chess_gray=cv2.cvtColor(flat_chess,cv2.COLOR_RGB2GRAY)
flat_chess_gray_=flat_chess_gray.copy()
flat_chess_=flat_chess.copy()

real_chess_gray=cv2.cvtColor(real_chess,cv2.COLOR_RGB2GRAY)
real_chess_gray_=real_chess_gray.copy()
real_chess_=real_chess.copy()

# %%
corners=cv2.goodFeaturesToTrack(image=flat_chess_gray,maxCorners=5,qualityLevel=0.01,minDistance=10)

# %%
corners
# Out:
# array([[[308., 308.]],
#
#        [[264., 308.]],
#
#        [[220., 308.]],
#
#        [[176., 308.]],
#
#        [[132., 308.]]], dtype=float32)

# %%
corners=np.int0(corners)
corners
# Out:
# array([[[308, 308]],
#
#        [[264, 308]],
#
#        [[220, 308]],
#
#        [[176, 308]],
#
#        [[132, 308]]], dtype=int64)

# %%
for i in corners:
    x,y=np.ravel(i)
    cv2.circle(flat_chess_,(x,y),3,(255,0,0),-1)

# %%
plt.imshow(flat_chess_)

# %%
corners=cv2.goodFeaturesToTrack(image=flat_chess_gray,maxCorners=64,qualityLevel=0.01,minDistance=10)
corners=np.int0(corners)

for i in corners:
    x,y=np.ravel(i)
    cv2.circle(flat_chess_,(x,y),3,(255,0,0),-1)
    
plt.imshow(flat_chess_)

# %%
corners=cv2.goodFeaturesToTrack(image=real_chess_gray,maxCorners=50,qualityLevel=0.01,minDistance=10)
corners=np.int0(corners)

for i in corners:
    x,y=np.ravel(i)
    cv2.circle(real_chess_,(x,y),3,(255,0,0),-1)

plt.imshow(real_chess_)

# %%
corners=cv2.goodFeaturesToTrack(image=real_chess_gray_,maxCorners=100,qualityLevel=0.01,minDistance=10)
corners=np.int0(corners)

for i in corners:
    x,y=np.ravel(i)
    cv2.circle(real_chess_,(x,y),3,(255,0,0),-1)


check=real_chess_.copy()
plt.imshow(real_chess_)

# %%
corners=cv2.goodFeaturesToTrack(image=real_chess_gray_,maxCorners=100,qualityLevel=0.01,minDistance=5)
corners=np.int0(corners)

for i in corners:
    x,y=np.ravel(i)
    cv2.circle(real_chess_,(x,y),3,(255,0,0),-1)
    
plt.imshow(real_chess_)

# %%
flat_chess_gray=cv2.cvtColor(flat_chess,cv2.COLOR_RGB2GRAY)
flat_chess_gray_=flat_chess_gray.copy()
flat_chess_=flat_chess.copy()

real_chess_gray=cv2.cvtColor(real_chess,cv2.COLOR_RGB2GRAY)
real_chess_gray_=real_chess_gray.copy()
real_chess_=real_chess.copy()

# %%
corners=cv2.goodFeaturesToTrack(image=real_chess_gray_,maxCorners=100,qualityLevel=0.05,minDistance=10)
corners=np.int0(corners)

for i in corners:
    x,y=np.ravel(i)
    cv2.circle(real_chess_,(x,y),3,(255,0,0),-1)


plt.imshow(real_chess_)

# %%
corners=cv2.goodFeaturesToTrack(image=real_chess_gray_,maxCorners=100,qualityLevel=0.01,minDistance=10)
corners=np.int0(corners)

for i in corners:
    x,y=np.ravel(i)
    cv2.circle(real_chess_,(x,y),3,(255,0,0),-1)


plt.imshow(real_chess_)
